# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Spectral analysis of simple signal

# %%
# load the signal
xt = np.loadtxt('signal_2.txt')

# %%
# plot the signal
plt.figure(figsize=(16,6))
plt.plot(xt), plt.grid(True);

# %% [markdown]
# **Q1.** Analyse the sampled signal in frequency domain using FFT. (The sampling frequency is $f_s=318$ Hz.)

# %%
#

# %% [markdown]
# **Q2.** Plot the time domain signal on its original time scale, assuming that the first sample taken is located at $t=0$.

# %%
#

# %% [markdown]
# **Q3.** Plot the spectrum of the signal. Estimate the frequency and the magnitude of the components!

# %%
#
