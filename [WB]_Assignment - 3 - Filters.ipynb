# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as sig

# %% [markdown]
# ### Filtering
#
# The sampled signals are stored in .txt files, we only know the values and the sampling frequency.

# %% [markdown]
# **Q1.** Analysis and processing of a signal.

# %%
# load the signal
# sampling freq: 4990 Hz
xt = np.loadtxt('signal_Q1.txt')

# %%
plt.figure(figsize=(14,6))
plt.plot(xt), plt.grid(True);

# %% [markdown]
# Given the sampled signal above. We know, that the signal is a sum of four sine signals with some additive noise. The sampling frequrency is: $f_s=4990 Hz$

# %% [markdown]
# **Q1. (a.)** Plot the signal on its original time scale!

# %%
#

# %% [markdown]
# **Q1. (b.)** Calculate the spectrum of the signal! Plot the spectrum vs. the frequency measured in Hz! What are the frequencies of the sine components of the signal?

# %%
#

# %% [markdown]
# **Q1. (c.)** Construct a high-pass FIR filter for keeping only the highest frequency component of the signal! Apply the filter to the signal and check the spectrum of the filtered signal!

# %%
#

# %% [markdown]
# **Q2.** Band-reject filter.

# %%
# load the signal
# sampling freq: 3995 Hz
xt = np.loadtxt('signal_Q2.txt')

# %%
plt.figure(figsize=(14,6))
plt.plot(xt), plt.grid(True);

# %% [markdown]
# Given the sampled signal above. We know, that the signal is a sum of four sine signals with some additive noise. The sampling frequency is $f_s = 3995 Hz$

# %% [markdown]
# **Q2. (a.)** Plot the spectrum of the signal vs. frequency measured in Hz!

# %%
#

# %% [markdown]
# **Q2. (b.)** Construct a band-reject filter for removing the component having the highest *amplitude*!

# %%
#

# %% [markdown]
# **Q2. (c.)** Plot the frequency response of the filter!

# %%
#

# %% [markdown]
# **Q2. (d.)** Apply the filter to the signal! Plot the spectrum of the filtered signal!

# %%
#

# %% [markdown]
# **Q3.** Notch filter.

# %%
# load the signal
# sampling freq: 7990 Hz
xt = np.loadtxt('signal_Q3.txt')

# %%
plt.figure(figsize=(14,6))
plt.plot(xt), plt.grid(True);

# %% [markdown]
# Given the sampled signal above. We know, that the signal is a sum of four sine signals with some additive noise. The sampling frequency is $f_s = 7990 Hz$

# %% [markdown]
# **Q3. (a.)** Plot the spectrum of the signal.

# %%
#

# %% [markdown]
# **Q3. (b.)** Construct a notch-filter for removing the component having the highest *amplitude*!

# %%
#

# %% [markdown]
# **Q3. (c.)** Plot the frequency response of the filter!

# %%
#
